# %%
# -*- coding: utf-8 -*-import twitter_config
import os,fnmatch,codecs
import re
import glob, os
import pandas as pd

pd.set_option('display.max_colwidth', -1)

path = r'F:\My GitHub Repos\twitter-persian-nlp\output\step1'
all_rec = glob.iglob(os.path.join(path, "*.txt"), recursive=True)
dataframes = (pd.read_csv(f,sep="\t",encoding="utf8",header=None,names=["ID","Text"]) for f in all_rec)
df = pd.concat(dataframes, ignore_index=True)

df.head(10)
# Out:
#                    ID  \
# 0  974765907028398083
# 1  974765908597067776
# 2  974765912837455872
# 3  974765913139564544
# 4  974765913277960192
# 5  974765914389442560
# 6  974765916033560577
# 7  974765916163661824
# 8  974765916331429888
# 9  974765919196065792
#
#                                                                                                                                                                                            Text
# 0  میزان پرداختی سود سپرده ها تو بانک های ایران با درامد نفتی و مالیات برابره یعنی کل درآمد کشور بصورت سود سپرده در اختیار رباخواران بانکی قرار میگیره با این حال میخوان بانک ها ورشکسته نشن  +
# 1    امیدوارکننده ترین آیه ای  که خواندم   ای بندگان من که درحقّ خوداسراف کرده اید ازرحمت خدامأیوس نشویدزیرااو همه گناهان رامی
# 2    من اگه میدونستم از روز اول خیلی از آدمارو آدم حساب نمیکردم
# 3  اين شادمهر چه ميكنه با ادم اونم شبا
# ...

# %%
df['word_count'] = df['Text'].apply(lambda x: len(str(x).split(" ")))
df.head()
# Out:
#                    ID  \
# 0  974765907028398083
# 1  974765908597067776
# 2  974765912837455872
# 3  974765913139564544
# 4  974765913277960192
#
#                                                                                                                                                                                            Text  \
# 0  میزان پرداختی سود سپرده ها تو بانک های ایران با درامد نفتی و مالیات برابره یعنی کل درآمد کشور بصورت سود سپرده در اختیار رباخواران بانکی قرار میگیره با این حال میخوان بانک ها ورشکسته نشن  +
# 1    امیدوارکننده ترین آیه ای  که خواندم   ای بندگان من که درحقّ خوداسراف کرده اید ازرحمت خدامأیوس نشویدزیرااو همه گناهان رامی
# 2    من اگه میدونستم از روز اول خیلی از آدمارو آدم حساب نمیکردم
# 3  اين شادمهر چه ميكنه با ادم اونم شبا
# 4    چطوری اسم یه آهنگ می‌تونه شراب باشه تو جمهوری اسلامی بدین گونه نفس بکش کنار من هوا پر از شراب شه که حال مردم جهان ت
#
#    word_count
# 0  38
# 1  24
# 2  14
# 3  8
# 4  28

# %%
def avg_word(sentence):
  words = str(sentence).split()
  return (sum(len(word) for word in words)/len(words))

df['avg_word'] = df['Text'].apply(lambda x: avg_word(x))
df.head()
# Out:
#                    ID  \
# 0  974765907028398083
# 1  974765908597067776
# 2  974765912837455872
# 3  974765913139564544
# 4  974765913277960192
#
#                                                                                                                                                                                            Text  \
# 0  میزان پرداختی سود سپرده ها تو بانک های ایران با درامد نفتی و مالیات برابره یعنی کل درآمد کشور بصورت سود سپرده در اختیار رباخواران بانکی قرار میگیره با این حال میخوان بانک ها ورشکسته نشن  +
# 1    امیدوارکننده ترین آیه ای  که خواندم   ای بندگان من که درحقّ خوداسراف کرده اید ازرحمت خدامأیوس نشویدزیرااو همه گناهان رامی
# 2    من اگه میدونستم از روز اول خیلی از آدمارو آدم حساب نمیکردم
# 3  اين شادمهر چه ميكنه با ادم اونم شبا
# 4    چطوری اسم یه آهنگ می‌تونه شراب باشه تو جمهوری اسلامی بدین گونه نفس بکش کنار من هوا پر از شراب شه که حال مردم جهان ت
#
#    word_count  avg_word
# 0  38          4.081081
# 1  24          4.950000
# ...

# %%
df['Text'].describe()
# Out:
# count     44286
# unique    32204
# top         زمان خانه‌تکانی بزرگ میهن فرا رسیده است ؛ نوروز حقیقی ايران در راه‌  است
# freq      85
# Name: Text, dtype: object

# %%
freq = pd.Series(' '.join(df['Text']).split()).value_counts()[:50]
freq
# Out:
# و        29397
# به       26557
# از       23565
# که       18283
# در       17334
# با       11919
# این      9082
# رو       8011
# را       6123
# هم       5847
# تو       5770
# من       5551
# است      4666
# یه       4161
# برای     3797
# ما       3430
# تا       3371
# یک       3158
# می       3046
# بود      3040
# سال      2923
# ایران    2814
# ها       2709
# های      2692
# همه      2491
# هر       2472
# شما      2468
# مردم     2394
# ولی      2289
# نه       2226
# شد       2188
# شده      2120
# نیست     2003
# چه       1914
# یکی      1889
# بعد      1883
# دیگه     1854
# كه       1849
# اون      1847
# ای       1834
# باید     1777
# یا       1752
# داره     1738
# فقط      1703
# بر       1674
# امروز    1600
# خیلی     1510
# کردن     1492
# خود      1486
# اگر      1466
# dtype: int64

# %%
freq = list(freq.index)
df['Text'] = df['Text'].apply(lambda x: " ".join(x for x in x.split() if x not in freq))
df['Text']
# Out:
# 0        میزان پرداختی سود سپرده بانک درامد نفتی مالیات برابره یعنی کل درآمد کشور بصورت سود سپرده اختیار رباخواران بانکی قرار میگیره حال میخوان بانک ورشکسته نشن +
# 1        امیدوارکننده ترین آیه خواندم بندگان درحقّ خوداسراف کرده اید ازرحمت خدامأیوس نشویدزیرااو گناهان رامی
# 2        اگه میدونستم روز اول آدمارو آدم حساب نمیکردم
# 3        اين شادمهر ميكنه ادم اونم شبا
# 4        چطوری اسم آهنگ می‌تونه شراب باشه جمهوری اسلامی بدین گونه نفس بکش کنار هوا پر شراب شه حال جهان ت
# 5        خانم مریم_رجوی استبداد مذهبی تنگنای چالش‌های چندگانه‌ جنبش اعتراضی نیرومند جنگ جانشینی ته‌کشیدن منابع
# 6        آقای جا شعار حمایت مستضعف سر بدهی مدعی عادل‌ترین حکومت جهان باشی انقلابت انقلاب مستضعفان جهان بدانی
# 7        لاسو بودن جاجو بودن خيلى بهتره توجيه ميكند
# 8        زندگي باري دوش ژنرال چگونه يك روح خون سرازير ميشود زندگي بايد همانگونه باشد ميخواهيم
# 9        شوق دیدار مرا نکشد می‌کشد غصه‌ی جدایی او بار الها ببخش گاهی زده‌ام حرفی خدایی او جهنم بهشت نگرانی چرا
# ...

# %%
freq = pd.Series(' '.join(df['Text']).split()).value_counts()[-20:]
freq
# Out:
# اپ‌ها                  1
# آشیق                   1
# نمیبخشماینقد           1
# افغانی‌تحقیره          1
# کتبا                   1
# آسمونو                 1
# پیکر_شهدا_دفاع_مقدس    1
# قورد                   1
# نموگوم                 1
# نمی‌فروشه؛             1
# تحربه‌ی                1
# فیلرا                  1
# غَفَرَ                 1
# طالبى                  1
# خبرگذاری               1
# پدرشه                  1
# زبان‌گنجشک‌های         1
# آسکشوال                1
# بسازمت                 1
# سني                    1
# dtype: int64

# %%
#g = df['Text'].unique()
df.to_csv(r'F:\My GitHub Repos\twitter-persian-nlp\output\step2\tweets_all.txt',sep='\t',index=False, encoding='utf-8',header=True,columns=["ID","word_count","Text"])
